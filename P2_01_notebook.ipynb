# %%
## Presentation des donnees

# %%
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("p2-arbres-fr (1).csv", sep=';')

# %%
data
# Out:
#              id type_emplacement domanialite     arrondissement  \
# 0         99874            Arbre      Jardin     PARIS 7E ARRDT
# 1         99875            Arbre      Jardin     PARIS 7E ARRDT
# 2         99876            Arbre      Jardin     PARIS 7E ARRDT
# 3         99877            Arbre      Jardin     PARIS 7E ARRDT
# 4         99878            Arbre      Jardin    PARIS 17E ARRDT
# 5         99879            Arbre      Jardin    PARIS 17E ARRDT
# 6         99880            Arbre      Jardin    PARIS 17E ARRDT
# 7         99881            Arbre      Jardin    PARIS 16E ARRDT
# 8         99882            Arbre      Jardin    PARIS 16E ARRDT
# 9         99883            Arbre      Jardin    PARIS 16E ARRDT
# 10        99884            Arbre      Jardin    PARIS 16E ARRDT
# 11        99885            Arbre      Jardin    PARIS 16E ARRDT
# 12        99887            Arbre      Jardin    PARIS 16E ARRDT
# 13        99888            Arbre      Jardin    PARIS 16E ARRDT
# ...

# %%
print("Dimensions de la table de donnees : {}".format(data.shape))
print("Nombre de donnees : {}".format(data.size))
print("Nombre de donnees manquantes : {}".format(data.isnull().sum()))
# Out:
# Dimensions de la table de donnees : (200137, 18)
# Nombre de donnees : 3602466
# Nombre de donnees manquantes : id                          0
# type_emplacement            0
# domanialite                 1
# arrondissement              0
# complement_addresse    169235
# numero                 200137
# lieu                        0
# id_emplacement              0
# libelle_francais         1497
# genre                      16
# espece                   1752
# variete                163360
# circonference_cm            0
# hauteur_m                   0
# stade_developpement     67205
# remarquable             63098
# geo_point_2d_a              0
# geo_point_2d_b              0
# dtype: int64

# %%
## Demarche d'analyse des donnees

# %%
data.loc[:,["circonference_cm", "hauteur_m", "geo_point_2d_a", "geo_point_2d_b"]].mean()
# Out:
# circonference_cm    83.380479
# hauteur_m           13.110509
# geo_point_2d_a      48.854491
# geo_point_2d_b       2.348208
# dtype: float64

# %%
import numpy as np
np.std(data.loc[:,["circonference_cm", "hauteur_m", "geo_point_2d_a", "geo_point_2d_b"]]) 
# presence de valeurs aberrantes dans les colonnes circonference_cm et hauteur_m car std>>moyennes

# %%
## presence de valeurs aberrantes dans les colonnes circonference_cm et hauteur_m
print(np.max(data.loc[:,["circonference_cm", "hauteur_m", "geo_point_2d_a", "geo_point_2d_b"]]))
print(np.quantile(data.loc[:,["circonference_cm"]], 0.99999))
print(np.quantile(data.loc[:,["hauteur_m"]], 0.99999))
# Out:
# circonference_cm    250255.000000
# hauteur_m           881818.000000
# geo_point_2d_a          48.911485
# geo_point_2d_b           2.469759
# dtype: float64
# 79100.94640007359
# 2524.306400002679

# %%
print("Medianes : {}".format(np.median(data.loc[:,["circonference_cm", "hauteur_m", "geo_point_2d_a", "geo_point_2d_b"]])))

datac.median(axis=0)
# Out:
# Medianes : 15.0
# circonference_cm    70.000000
# hauteur_m            8.000000
# geo_point_2d_a      48.854162
# geo_point_2d_b       2.351095
# dtype: float64

# %%
data.describe().T
# Out:
#                      count           mean            std           min  \
# id                200137.0  387202.682308  545603.242357  99874.000000
# numero                 0.0            NaN            NaN           NaN
# circonference_cm  200137.0      83.380479     673.190213      0.000000
# hauteur_m         200137.0      13.110509    1971.217387      0.000000
# remarquable       137039.0       0.001343       0.036618      0.000000
# geo_point_2d_a    200137.0      48.854491       0.030234     48.742290
# geo_point_2d_b    200137.0       2.348208       0.051220      2.210241
#
#                             25%            50%            75%           max
# id                155927.000000  221078.000000  274102.000000  2.024745e+06
# numero                      NaN            NaN            NaN           NaN
# circonference_cm      30.000000      70.000000     115.000000  2.502550e+05
# hauteur_m              5.000000       8.000000      12.000000  8.818180e+05
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, iplot
import plotly.figure_factory as ff
import cufflinks
cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
import plotly.graph_objs as go
import plotly
from plotly import tools


fig, ax = plt.subplots()
# data.loc[:,["circonference_cm", "hauteur_m", "geo_point_2d_a", "geo_point_2d_b"]].plot(ax=ax)
data.loc[:,["circonference_cm"]].plot(ax=ax, title='circonference en cm' )
plt.xlabel('id')
plt.ylabel('cm')
plt.show()
fig1, ax1 = plt.subplots()
# data.loc[:,["circonference_cm"]].plot(kind='hist',bins=100,ax=ax)
data.loc[:,["circonference_cm"]].plot(kind='box',ax=ax1)
plt.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
## Synthese

# %%
### Le jeu de donnees est incomplet : 
###  Le champ numero est une colonne vide
###  Le jeu de donnees est aussi erronne, des valeurs aberrantes y sont presentes au niveau de la circonference et la hauteur des arbres
###  Pour la circonference le fait de prendre 3*std n'est pas realiste. en effet la circonference d'un arbre sur terre est de 500 cm.
###  Idem pour la hauteur maximale d'un arbre qui est de 63 metres

# %% [markdown]
# ## tests markdowns
# ## ![Jupyter logo]
# (https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg)

# %% [markdown]
# ![Google logo](https://www.google.fr/images/srpr/logo11w.png "google logo")
